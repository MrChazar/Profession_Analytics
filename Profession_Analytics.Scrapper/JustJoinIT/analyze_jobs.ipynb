# %%
import pandas as pd
import numpy as np
import json
from pandas import json_normalize
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Wczytaj dane z pliku JSON
with open('jobs.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

print(data)
# Zamień dane na DataFrame
df = json_normalize(data, sep='_')
print(df)

# Zapisz DataFrame do pliku CSV
df.to_csv('jobs.csv', index=False)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df['publishedAt'] = pd.to_datetime(df['publishedAt']).dt.strftime('%Y-%m-%d')

# %%
plt.figure(figsize=(20, 20))
plt.tight_layout()
plt.hist(df['publishedAt'])


plt.title("Prace dodane na przestrzeni dni")
# Out:
# Text(0.5, 1.0, 'Prace dodane na przestrzeni dni')

# %%
existing_jobs = sc.load_existing_jobs("jobs.json")
sc.save_to_mongodb(existing_jobs)
# Out:
# Zapisano 8716 ofert pracy do MongoDB.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 4
#       2 existing_jobs = sc.load_existing_jobs("jobs.json")
#       3 sc.save_to_mongodb(existing_jobs)
# ----> 4 jobs = sc.load_from_mongodb()
#       5 print(jobs)
#
# AttributeError: module 'script' has no attribute 'load_from_mongodb'

# %%
import script as sc
jobs = sc.load_from_mongodb()
jobs
# Out:
# [{'_id': ObjectId('66fd82438a88e082aabc8add'),
#   'slug': 'jysk-sprzedawca-jysk-ul-pulawska-warszawa-pelny-etat--warszawa-sales-praca-w-sklepie',
#   'title': 'Sprzedawca JYSK ul. Puławska Warszawa (Pełny etat)',
#   'requiredSkills': ['sumienność',
#    'sprzedaż',
#    'dobra organizacja',
#    'praca w grupie',
#    'elastyczność',
#    'skuteczna komunikacja'],
#   'niceToHaveSkills': ['merchandising'],
#   'workplaceType': 'office',
#   'workingTime': 'full_time',
#   'experienceLevel': 'junior',
#   'employmentTypes': [{'to': 5100,
#     'from': 5100,
#     'type': 'permanent',
#     'gross': True,
#     'to_chf': 1120.8168,
#     'to_eur': 1190.7633,
#     'to_gbp': 991.083,
#     'to_pln': 5100,
#     'to_usd': 1325.5869,
#     'currency': 'pln',
#     'from_chf': 1120.8168,
#     'from_eur': 1190.7633,
#     'from_gbp': 991.083,
#     'from_pln': 5100,
#     'from_usd': 1325.5869}],
#   'categoryId': 66,
#   'multilocation': [{'city': 'Warszawa',
# ...
