# %%
import pandas as pd
import numpy as np
import json
from pandas import json_normalize

# %%
# Wczytaj dane z pliku JSON
with open('jobs.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

print(data)
# Zamień dane na DataFrame
df = json_normalize(data, sep='_')
print(df)

# Zapisz DataFrame do pliku CSV
df.to_csv('jobs.csv', index=False)

# Jeśli chcesz zapisać DataFrame do pliku Excel:
df.to_excel('jobs.xlsx', index=False)
# Out:
# [{'slug': 'eveline-cosmetics-copywriter-e-commerce-lesznowola-marketing-content-copywriting-4bb6e236', 'title': 'Copywriter E-commerce', 'requiredSkills': ['copywriting', 'beauty', 'SEO'], 'niceToHaveSkills': 'brak informacji', 'workplaceType': 'office', 'workingTime': 'full_time', 'experienceLevel': 'mid', 'employmentTypes': [{'to': 8000, 'from': 6000, 'type': 'permanent', 'gross': True, 'to_chf': 1757.464, 'to_eur': 1867.128, 'to_gbp': 1577.048, 'to_pln': 8000, 'to_usd': 2069.64, 'currency': 'pln', 'from_chf': 1318.098, 'from_eur': 1400.346, 'from_gbp': 1182.786, 'from_pln': 6000, 'from_usd': 1552.23}, {'to': 8000, 'from': 6000, 'type': 'b2b', 'gross': False, 'to_chf': 1757.464, 'to_eur': 1867.128, 'to_gbp': 1577.048, 'to_pln': 8000, 'to_usd': 2069.64, 'currency': 'pln', 'from_chf': 1318.098, 'from_eur': 1400.346, 'from_gbp': 1182.786, 'from_pln': 6000, 'from_usd': 1552.23}], 'categoryId': 6, 'multilocation': [{'city': 'Lesznowola', 'slug': 'eveline-cosmetics-copywriter-e-commerce-lesznowola-marketing-content-copywriting-4bb6e236', 'street': 'Żytnia 19', 'latitude': 52.100734, 'longitude': 20.925877}, {'city': 'Piaseczno', 'slug': 'eveline-cosmetics-copywriter-e-commerce-piaseczno-marketing-content-copywriting-1b7be92f', 'street': '-', 'latitude': 52.0811536, 'longitude': 21.0238602}, {'city': 'Warszawa', 'slug': 'eveline-cosmetics-copywriter-e-commerce-warszawa-marketing-content-copywriting-429b268e', 'street': '-', 'latitude': 52.2296756, 'longitude': 21.0122287}], 'city': 'Lesznowola', 'street': 'Żytnia 19', 'latitude': '52.1007340', 'longitude': '20.9258770', 'remoteInterview': False, 'companyName': 'Eveline Cosmetics', 'companyLogoThumbUrl': 'https://imgproxy.justjoinit.tech/RPUfoiBuxcdvEI8LnrsJ8blTP9uFIKnaOq8W4pYuAfA/h:200/w:200/plain/https://imgproxy.justjoinit.tech/cVpupkMZ4Plf_nqKpyol6TBwRTrr86MtYTJOgns-idk/h:200/w:200/plain/https://imgproxy.justjoinit.tech/WtTiHXHYujjrth7aF_7qI2EpiCsqP269bjawUjmvIeI/h:200/w:200/plain/https://imgproxy.justjoinit.tech/yrdueOGda4kOz32x2fFGeWj5pexoMMHTMT4dFpIKZjk/h:200/w:200/plain/https://public.rocketjobs.pl/companies/logos/original/ede9fdfdc0a0c6fe48633f901f0361be2ccef302.jpg', 'publishedAt': '2024-09-14T22:00:27.462Z', 'openToHireUkrainians': False}, {'slug': 'a-s-sp-z-o-o--specjalista--ka-ds-relacji-z-uzytkownikami-krakow-support', 'title': 'Specjalista(-ka) ds. Relacji z Użytkownikami', 'requiredSkills': ['doradztwo', 'excel', 'CRM', 'dobra organizacja pracy'], 'niceToHaveSkills': ['elastyczność', 'konsultant', 'multitasking'], 'workplaceType': 'hybrid', 'workingTime': 'full_time', 'experienceLevel': 'mid', 'employmentTypes': [{'to': 12000, 'from': 4000, 'type': 'b2b', 'gross': False, 'to_chf': 2636.196, 'to_eur': 2800.692, 'to_gbp': 2365.572, 'to_pln': 12000, 'to_usd': 3104.46, 'currency': 'pln', 'from_chf': 878.732, 'from_eur': 933.564, 'from_gbp': 788.524, 'from_pln': 4000, 'from_usd': 1034.82}, {'to': 12000, 'from': 4000, 'type': 'mandate_contract', 'gross': True, 'to_chf': 2636.196, 'to_eur': 2800.692, 'to_gbp': 2365.572, 'to_pln': 12000, 'to_usd': 3104.46, 'currency': 'pln', 'from_chf': 878.732, 'from_eur': 933.564, 'from_gbp': 788.524, 'from_pln': 4000, 'from_usd': 1034.82}], 'categoryId': 43, 'multilocation': [{'city': 'Kraków', 'slug': 'a-s-sp-z-o-o--specjalista--ka-ds-relacji-z-uzytkownikami-krakow-support', 'street': 'Rynek Główny 39', 'latitude': 50.0627234, 'longitude': 19.9376301}], 'city': 'Kraków', 'street': 'Rynek Główny 39', 'latitude': '50.0627234', 'longitude': '19.9376301', 'remoteInterview': False, 'companyName': 'A&S sp. z o.o.', 'companyLogoThumbUrl': 'https://imgproxy.justjoinit.tech/TrZchuSCOUpaP8yIOyp_TC3emkfBMaa9Phhh-fFhJTI/h:200/w:200/plain/https://imgproxy.justjoinit.tech/-_EYAGfqNfNpIYqCF3Sg8Uu3Cj8YGfbUh0-cmQo9WcE/h:200/w:200/plain/https://public.rocketjobs.pl/companies/logos/original/31ed44ec0456b180ef6abde8b368b61e92170efc.jpeg', 'publishedAt': '2024-09-14T21:00:31.751Z', 'openToHireUkrainians': False}, {'slug': 'eveline-cosmetics-e-commerce-market ...
#                                                   slug  \
# 0    eveline-cosmetics-copywriter-e-commerce-leszno...
# 1    a-s-sp-z-o-o--specjalista--ka-ds-relacji-z-uzy...
# 2    eveline-cosmetics-e-commerce-marketing-manager...
# 3    car-lease-polska-sp-z-o-o--specjalista-seo-sen...
# 4    maobi-group-sp-z-o-o--kierowca-ce---task-force...
# ..                                                 ...
# 395     tarczynski-s-a--koordynator-ds-ppoz-wroclaw-pm
# 396  tarczynski-s-a--kierownik-transportu-wroclaw-l...
# 397  mccann-poland-graphic-designer-warszawa-design...
# 398  tarczynski-s-a--starszy-specjalista-ds-rekruta...
# 399  redats-sp-z-o-o--specjalista-ds-contentu-marke...
#
#                                              title  \
# 0                            Copywriter E-commerce
# 1     Specjalista(-ka) ds. Relacji z Użytkownikami
# 2    E-commerce Marketing Manager (Ukraine) she/he
# 3                           Specjalista SEO Senior
# 4      Kierowca CE – Task Force / Skoczek - Niemcy
# ..                                             ...
# 395                           Koordynator ds. PPOŻ
# 396                           Kierownik Transportu
# 397                             Graphic Designer 🎨
# 398             Starszy Specjalista ds. Rekrutacji
# 399        Specjalista ds. contentu marketingowego
#
#                                         requiredSkills  \
# 0                           [copywriting, beauty, SEO]
# 1     [doradztwo, excel, CRM, dobra organizacja pracy]
# 2      [Sales, ecommerce, ukraine, marketing, magento]
# 3                                       [SEM, SEO, ux]
# 4    [elastyczność, prawo jazdy, odpowiedzialność, ...
# ..                                                 ...
# 395       [PPOŻ, prawo jazdy, dobra organizacja pracy]
# 396  [Transport, logistyka, dobra organizacja pracy...
# 397  [Adobe Creative Suite, kreatywność, design, pr...
# 398  [sourcing, prawo jazdy, komunikatywoność, Rekr...
# 399  [copywriting, dobra organizacja pracy, SEO, ma...
#
#                              niceToHaveSkills workplaceType workingTime  \
# 0                             brak informacji        office   full_time
# 1    [elastyczność, konsultant, multitasking]        hybrid   full_time
# 2                             brak informacji        office   full_time
# 3                             brak informacji        office   full_time
# 4                                 [Angielski]        office   full_time
# ..                                        ...           ...         ...
# 395                           brak informacji        office   full_time
# 396                           brak informacji        office   full_time
# 397                           brak informacji        hybrid   full_time
# 398                           brak informacji        office   full_time
# 399                           brak informacji        office   full_time
#
#     experienceLevel                                    employmentTypes  \
# 0               mid  [{'to': 8000, 'from': 6000, 'type': 'permanent...
# 1               mid  [{'to': 12000, 'from': 4000, 'type': 'b2b', 'g...
# 2           c_level  [{'to': 18000, 'from': 12000, 'type': 'permane...
# 3            senior  [{'to': 10000, 'from': 8000, 'type': 'permanen...
# 4               mid  [{'to': 3400, 'from': 3200, 'type': 'any', 'gr...
# ..              ...                                                ...
# 395             mid  [{'to': None, 'from': None, 'type': 'permanent...
# 396          senior  [{'to': None, 'from': None, 'type': 'permanent...
# 397             mid  [{'to': None, 'from': None, 'type': 'b2b', 'gr...
# 398          senior  [{'to': None, 'from': None, 'type': 'permanent...
# 399             mid  [{'to': None, 'from': None, 'type': 'permanent...
#
#      categoryId                                      multilocation  \
# 0             6  [{'city': 'Lesznowola', 'slug': 'eveline-cosme...
# 1            43  [{'city': 'Kraków', 'slug': 'a-s-sp-z-o-o--spe...
# 2             7  [{'city': 'Lesznowola', 'slug': 'eveline-cosme...
# 3            40  [{'city': 'Gdynia', 'slug': 'car-lease-polska-...
# 4            63  [{'city': 'Niemcy', 'slug': 'maobi-group-sp-z-...
# ..          ...                                                ...
# 395          41  [{'city': 'Wrocław', 'slug': 'tarczynski-s-a--...
# 396          48  [{'city': 'Wrocław', 'slug': 'tarczynski-s-a--...
# 397          26  [{'city': 'Warszawa', 'slug': 'mccann-poland-g...
# 398          31  [{'city': 'Wrocław', 'slug': 'tarczynski-s-a--...
# 399           6  [{'city': 'Lublin', 'slug': 'redats-sp-z-o-o--...
#
#            city            street    latitude   longitude  remoteInterview  \
# 0    Lesznowola         Żytnia 19  52.1007340  20.9258770            False
# 1        Kraków   Rynek Główny 39  50.0627234  19.9376301            False
# 2    Lesznowola         Żytnia 19  52.1007340  20.9258770            False
# 3        Gdynia  Władysława IV 43  54.5123900  18.5381550            False
# 4        Niemcy               tbc  51.1656910  10.4515260             True
# ..          ...               ...         ...         ...              ...
# 395     Wrocław                 -  51.1092948  17.0386019            False
# 396     Wrocław                 -  51.1092948  17.0386019            False
# 397    Warszawa      Koszykowa 59  52.2224070  21.0121039             True
# 398     Wrocław                 -  51.1092948  17.0386019            False
# 399      Lublin            Lublin  51.2509458  22.5747275            False
#
#                      companyName  \
# 0              Eveline Cosmetics
# 1                 A&S sp. z o.o.
# 2              Eveline Cosmetics
# 3    Car Lease Polska sp. z o.o.
# 4         MAOBI GROUP Sp. z o.o.
# ..                           ...
# 395              Tarczyński S.A.
# 396              Tarczyński S.A.
# 397                McCANN Poland
# 398              Tarczyński S.A.
# 399            REDATS Sp. z o.o.
#
#                                    companyLogoThumbUrl  \
# 0    https://imgproxy.justjoinit.tech/RPUfoiBuxcdvE...
# 1    https://imgproxy.justjoinit.tech/TrZchuSCOUpaP...
# 2    https://imgproxy.justjoinit.tech/cVpupkMZ4Plf_...
# 3    https://imgproxy.justjoinit.tech/JbRh55cKzQ27p...
# 4    https://imgproxy.justjoinit.tech/sJlMoYFmy3SOd...
# ..                                                 ...
# 395  https://imgproxy.justjoinit.tech/_oflmD8h0XcjO...
# 396  https://imgproxy.justjoinit.tech/_oflmD8h0XcjO...
# 397  https://imgproxy.justjoinit.tech/_WbO77ViaN_n6...
# 398  https://imgproxy.justjoinit.tech/_oflmD8h0XcjO...
# 399  https://imgproxy.justjoinit.tech/mOUQuDwnxQUag...
#
#                   publishedAt  openToHireUkrainians
# 0    2024-09-14T22:00:27.462Z                 False
# 1    2024-09-14T21:00:31.751Z                 False
# 2    2024-09-14T21:00:31.751Z                  True
# 3    2024-09-14T19:00:33.990Z                  True
# 4    2024-09-14T19:00:33.990Z                 False
# ..                        ...                   ...
# 395  2024-09-14T09:00:06.015Z                 False
# 396  2024-09-14T09:00:06.015Z                 False
# 397  2024-09-14T09:00:06.015Z                  True
# 398  2024-09-14T09:00:06.015Z                 False
# 399  2024-09-14T09:00:06.015Z                 False
#
# [400 rows x 19 columns]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 14
#      11 df.to_csv('jobs.csv', index=False)
#      13 # Jeśli chcesz zapisać DataFrame do pliku Excel:
# ---> 14 df.to_excel('jobs.xlsx', index=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)
#      66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'
